# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4]
y = [10,20,25,30]
plt.plot(x,y)
plt.ylabel('some numbers')
#plt.xticks(ticks=range(1,20))
#plt.xticks(ticks = [0,0.1,0.5,1,2])
plt.xticks(np.arange(0, 100, step=10))
plt.show()
